# %% [markdown]
# ## Reddit Hackathon

# %% [markdown]
# ### Import Necessary dependencies here

# %%
import dnalab
import spacy 
import pandas as pd
import os

# !pip3 install -U spacy
# !python3 -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /opt/conda/lib/python3.8/site-packages (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (4.54.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (1.19.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy) (49.6.0.post20210108)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.11.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (20.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (3.0.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /opt/conda/lib/python3.8/site-packages (from spacy) (1.7.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.23.0)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy) (8.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /opt/conda/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (3.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 12.8 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.54.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.23.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.8)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (49.6.0.post20210108)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /opt/conda/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ### Use `en_core_web_sm` model from spacy for better accuracy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
PROJECT_PATH = os.getcwd()
POSTS_PATH = 'data/reddit_posts'
COMMENTS_PATH = 'data/reddit_comments'
POSTS_DATA_PATH = os.path.join(PROJECT_PATH, POSTS_PATH)
COMMENTS_DATA_PATH = os.path.join(PROJECT_PATH, COMMENTS_PATH)

# %% [markdown]
# ### Load CSV Files into a Pandas Dataframe
#
# Go through all the files in the reddit_posts and reddit_comments directory and load them into a pandas df

# %%
def get_df(input_path, output_path):
    all_files = glob.glob(input_path + "/*.csv")

    dfs = []

    for filename in all_files:
        df = pd.read_csv(filename, index_col=None)
        dfs.append(df)

    df = pd.concat(dfs, axis=0, ignore_index=True)
    non_nan_df = df[df['text'].notna()]
    filtered_df = non_nan_df[(non_nan_df['text'] != "[removed]") & (
        non_nan_df['text'] != '[deleted]')]
    filtered_df['date'] = filtered_df['timestamp'].apply(
        lambda x: datetime.fromtimestamp(x)).tolist()
    filtered_df.set_index('date', inplace=True)
    final_df = filtered_df.drop(filtered_df.columns[0], axis=1)
    final_df = final_df.sort_index()
    final_df = final_df[final_df.index.month == 3]
    final_df.to_csv(output_path)
    

    
def get_input(data_path, column):
    df = pd.read_csv(data_path, index_col='date', parse_dates=True)
    res = df[column].tolist()
    return res

# %% [markdown]
# ### Specify Blacklist
#
# This should be extended to include more words according to Reddit posts/comments

# %%
BLACKLIST = ['bot', 'nyse', 'wsb', 'stock', 'mod', 'yolo', 'sec']

# %% [markdown]
# ### Extract Symbols

# %%
def process(raw_comment, nlp):
    doc = nlp(raw_comment)
    tokens = []
    res = None
    for ent in doc.ents:
        if ent.text.lower() not in BLACKLIST and ent.label_ == "ORG":
            tokens.append(str(ent))
            
    if len(tokens) > 0:
        res = ", ".join(tokens)
    return res

# %%
posts_df = pd.read_csv(os.path.join(PROJECT_PATH, 'data/posts_df.csv'), parse_dates=True)
posts_df['type'] = 'P'

# %%
comments_df = pd.read_csv(os.path.join(PROJECT_PATH, 'data/comments_df.csv'), parse_dates=True)
comments_df['type'] = 'C'

# %%
posts_df.head(10)
# Out:
#                   date post_id  \
# 0  2021-03-02 09:25:06  lw4h9d
# 1  2021-03-02 09:25:57  lw4i0b
# 2  2021-03-02 09:26:04  lw4i3o
# 3  2021-03-02 09:26:29  lw4ihe
# 4  2021-03-02 09:26:36  lw4ilh
# 5  2021-03-02 09:26:47  lw4is2
# 6  2021-03-02 09:27:06  lw4j12
# 7  2021-03-02 09:27:42  lw4jj8
# 8  2021-03-02 09:27:57  lw4jqn
# 9  2021-03-02 09:28:07  lw4juw
#
#                                                 text  \
# 0  So loving this GME still going strong, that I ...
# 1  Is this being pushed here.  Been shareholder f...
# 2  Gentlemen,\n\nNow that the yield bubble is pop...
# 3  CVSI is on the move up! Buy low sell high! Hav...
# 4  There is probably some rule against this threa...
# 5                                      Fk these mods
# 6                              Because apparently so
# 7  🚀🚀🚀 BankOfSabadell  🚀🚀🚀🚀\n\n*Processing img 0b...
# 8  Mods surely know that no GME thread = spam in ...
# 9   CBD Life Sciences Inc. is up today.  It's a C...
#
#                                              title  upvote_ratio   timestamp  \
# 0                   GME and the righteous options?           1.0  1614698706
# 1                                 Rocket Companies           1.0  1614698757
# 2               Cathie Wood said PLTR is mandatory           1.0  1614698764
# 3                                             CVSI           1.0  1614698789
# 4  NOT the GME thread but share your thoughts here           1.0  1614698796
# 5                               Gee Emm Eey 3/2/21           1.0  1614698807
# 6                     RKT MEGATHREAD March 2, 2020           1.0  1614698826
# 7                          BankOfSanadell -- Spain           1.0  1614698862
# 8                     Something fishy is going on?           1.0  1614698877
# 9                                          CBDL Up           1.0  1614698887
#
#                author type
# 0      Kick-Effective    P
# 1     Master-Unit6692    P
# 2  boomerbubblebuster    P
# 3           BigShr1mp    P
# 4   SwedishKillerChef    P
# 5        Mosaikmuster    P
# 6              iamzyb    P
# 7             NoFlySS    P
# 8     Crowbar_Freeman    P
# 9      ThisGuyAlright    P

# %%
comments_df.head(10)
# Out:
#                   date comment_id  \
# 0  2021-03-02 09:27:05    gpf8jcq
# 1  2021-03-02 09:27:25    gpf8ky5
# 2  2021-03-02 09:28:03    gpf8nvm
# 3  2021-03-02 09:28:07    gpf8o7q
# 4  2021-03-02 09:29:00    gpf8sfw
# 5  2021-03-02 09:29:38    gpf8vfy
# 6  2021-03-02 09:29:40    gpf8vly
# 7  2021-03-02 09:29:45    gpf8vyp
# 8  2021-03-02 09:29:46    gpf8w2i
# 9  2021-03-02 09:29:55    gpf8wqh
#
#                                                 text  score  awards  \
# 0  Heavy resistance at 124! Needs to move through...      1       0
# 1  Honestly mods why didn't you make an actual GM...      2       0
# 2                                            Squeeze      2       0
# 3                              And there she goes (:      2       0
# 4  Boom you see how quick she ran after blasting ...      1       0
# 5            No shit!\n\nhttps://fintel.io/ss/us/rkt      1       0
# 6                           Let's just talk GME here      3       0
# 7                                                 Fr      1       0
# 8             Holding RKT and GME. Suck on that Mods      1       0
# 9                            RKT TO THE MOON!!! 🚀🚀🌚🌚      1       0
#
#     timestamp               author  \t\t type
# 0  1614698825              jsams14   NaN    C
# 1  1614698845    SwedishKillerChef   NaN    C
# 2  1614698883          elliskj1979   NaN    C
# 3  1614698887              SARMY1K   NaN    C
# 4  1614698940              jsams14   NaN    C
# 5  1614698978     robertleeblairjr   NaN    C
# 6  1614698980  HouseDowningVicodin   NaN    C
# 7  1614698985     420yolotrillswag   NaN    C
# 8  1614698986        gswblu3-1lead   NaN    C
# 9  1614698995            Young0Ice   NaN    C

# %%
comments_df = comments_df[['comment_id', 'text', 'timestamp', 'type']]
posts_df = posts_df[['post_id', 'text', 'timestamp', 'type']]

# %%
comments_df = comments_df.loc[1:100, :]
posts_df = posts_df.loc[1:100, :]

# %%
comments_df['symbol'] = comments_df['text'].apply(lambda x: process(x, nlp))

# %%
comments_df.head(10)
# Out:
#    comment_id                                               text   timestamp  \
# 1     gpf8ky5  Honestly mods why didn't you make an actual GM...  1614698845
# 2     gpf8nvm                                            Squeeze  1614698883
# 3     gpf8o7q                              And there she goes (:  1614698887
# 4     gpf8sfw  Boom you see how quick she ran after blasting ...  1614698940
# 5     gpf8vfy            No shit!\n\nhttps://fintel.io/ss/us/rkt  1614698978
# 6     gpf8vly                           Let's just talk GME here  1614698980
# 7     gpf8vyp                                                 Fr  1614698985
# 8     gpf8w2i             Holding RKT and GME. Suck on that Mods  1614698986
# 9     gpf8wqh                            RKT TO THE MOON!!! 🚀🚀🌚🌚  1614698995
# 10    gpf8xim                               It is coming for you  1614699005
#
#    type symbol
# 1     C    GME
# 2     C   None
# 3     C   None
# 4     C   None
# 5     C   None
# 6     C    GME
# 7     C   None
# 8     C    GME
# 9     C   🚀🚀🌚🌚
# 10    C   None

# %%
posts_df['symbol'] = posts_df['text'].apply(lambda x: process(x, nlp))

# %%
posts_df.head(10)
# Out:
#    post_id                                               text   timestamp  \
# 1   lw4i0b  Is this being pushed here.  Been shareholder f...  1614698757
# 2   lw4i3o  Gentlemen,\n\nNow that the yield bubble is pop...  1614698764
# 3   lw4ihe  CVSI is on the move up! Buy low sell high! Hav...  1614698789
# 4   lw4ilh  There is probably some rule against this threa...  1614698796
# 5   lw4is2                                      Fk these mods  1614698807
# 6   lw4j12                              Because apparently so  1614698826
# 7   lw4jj8  🚀🚀🚀 BankOfSabadell  🚀🚀🚀🚀\n\n*Processing img 0b...  1614698862
# 8   lw4jqn  Mods surely know that no GME thread = spam in ...  1614698877
# 9   lw4juw   CBD Life Sciences Inc. is up today.  It's a C...  1614698887
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
#
#    type                          symbol
# 1     P                            None
# 2     P                            PLTR
# 3     P                            CVSI
# 4     P                             GME
# 5     P                            None
# 6     P                            None
# 7     P                            None
# 8     P                             GME
# 9     P  CBD Life Sciences Inc., Amazon
# 10    P               FDA, NPS, TAM, EV

# %% [markdown]
# # beam_width :
#
# Number of alternate analyses to consider. More is slower, and not necessarily better -- you need to experiment on your problem. (by default : 1)
#
# # beam_density :
#
# This clips solutions at each step. We multiply the score of the top-ranked action by this value, and use the result as a threshold. This prevents the parser from exploring options that look very unlikely, saving a bit of efficiency. Accuracy may also improve, because we've trained on greedy objective. (by default : 0)

# %%
from collections import defaultdict

def filter_low_confidence_entities(entities, cutoff=0.1):
    return {key: value for key, value in entities.items() if value > cutoff}

def get_momentum(text):
    doc = nlp.make_doc(text)
    beams = nlp.get_pipe("ner").beam_parse([doc], beam_width=1, beam_density=0.0000)
    entity_scores = defaultdict(float)
    total_score = 0
    for score, ents in nlp.get_pipe("ner").moves.get_beam_parses(beams[0]):
        total_score += score
        for start, end, label in ents:
            entity_scores[(start, end, label)] += score

    normalized_beam_score = {k: v/total_score for k, v in entity_scores.items()}
    confident_entities = filter_low_confidence_entities(normalized_beam_score)
    
    confident_entity_texts = {}
    
    for k, v in confident_entities.items():
        if k[2] == 'ORG':
            confident_entity_texts[str(doc[int(k[0]): int(k[1])])] = v*10

    return confident_entity_texts

# %%
comments_df = comments_df[comments_df['symbol'].notnull()]
comments_df['momentum_factor'] = comments_df['text'].apply(get_momentum)

# %%
posts_df = posts_df[posts_df['symbol'].notnull()]
posts_df['momentum_factor'] = posts_df['text'].apply(get_momentum)

# %%
comment_ticker_split = comments_df['symbol'].str.split(',').apply(pd.Series, 1).stack()
comment_ticker_split.index = comment_ticker_split.index.droplevel(-1)
comment_ticker_split.name = 'symbol'
del comments_df['symbol']
comment_ticker_split_df = comments_df.join(comment_ticker_split)

# %%
comment_ticker_split_df.head(10)
# Out:
#    comment_id                                               text   timestamp  \
# 1     gpf8ky5  Honestly mods why didn't you make an actual GM...  1614698845
# 6     gpf8vly                           Let's just talk GME here  1614698980
# 8     gpf8w2i             Holding RKT and GME. Suck on that Mods  1614698986
# 9     gpf8wqh                            RKT TO THE MOON!!! 🚀🚀🌚🌚  1614698995
# 11    gpf8xou                                         I like GME  1614699007
# 14    gpf8yoh     This sub isn’t just a GME cesspool, jfc people  1614699021
# 15    gpf8z1l  So apparently GME thread gets deleted in SECON...  1614699025
# 19    gpf92y2  Very fishy...  no zjz posts no Unpopular pinnn...  1614699076
# 19    gpf92y2  Very fishy...  no zjz posts no Unpopular pinnn...  1614699076
# 22    gpf93e3  ![img](emote|wsb_emojis|bull) on CCIV / PLTR (...  1614699081
#
#    type                   momentum_factor         symbol
# 1     C                     {'GME': 10.0}            GME
# 6     C                     {'GME': 10.0}            GME
# 8     C                     {'GME': 10.0}            GME
# 9     C                    {'🚀🚀🌚🌚': 10.0}           🚀🚀🌚🌚
# 11    C                     {'GME': 10.0}            GME
# 14    C                     {'GME': 10.0}            GME
# 15    C                     {'GME': 10.0}            GME
# 19    C  {'Unpopular': 10.0, 'GME': 10.0}      Unpopular
# 19    C  {'Unpopular': 10.0, 'GME': 10.0}            GME
# 22    C      {'CCIV / PLTR (Aside': 10.0}  CCIV / PLTR (

# %%
post_ticker_split = posts_df['symbol'].str.split(',').apply(pd.Series, 1).stack()
post_ticker_split.index = post_ticker_split.index.droplevel(-1)
post_ticker_split.name = 'symbol'
del posts_df['symbol']
post_ticker_split_df = posts_df.join(post_ticker_split)

# %%
post_ticker_split_df.head(10)
# Out:
#    post_id                                               text   timestamp  \
# 2   lw4i3o  Gentlemen,\n\nNow that the yield bubble is pop...  1614698764
# 3   lw4ihe  CVSI is on the move up! Buy low sell high! Hav...  1614698789
# 4   lw4ilh  There is probably some rule against this threa...  1614698796
# 8   lw4jqn  Mods surely know that no GME thread = spam in ...  1614698877
# 9   lw4juw   CBD Life Sciences Inc. is up today.  It's a C...  1614698887
# 9   lw4juw   CBD Life Sciences Inc. is up today.  It's a C...  1614698887
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
#
#    type                                    momentum_factor  \
# 2     P                                     {'PLTR': 10.0}
# 3     P                                     {'CVSI': 10.0}
# 4     P                                      {'GME': 10.0}
# 8     P                                      {'GME': 10.0}
# 9     P   {'CBD Life Sciences Inc.': 10.0, 'Amazon': 10.0}
# 9     P   {'CBD Life Sciences Inc.': 10.0, 'Amazon': 10.0}
# 10    P  {'FDA': 10.0, 'NPS': 10.0, 'TAM': 10.0, 'EV': ...
# 10    P  {'FDA': 10.0, 'NPS': 10.0, 'TAM': 10.0, 'EV': ...
# 10    P  {'FDA': 10.0, 'NPS': 10.0, 'TAM': 10.0, 'EV': ...
# 10    P  {'FDA': 10.0, 'NPS': 10.0, 'TAM': 10.0, 'EV': ...
#
#                     symbol
# 2                     PLTR
# 3                     CVSI
# 4                      GME
# 8                      GME
# 9   CBD Life Sciences Inc.
# 9                   Amazon
# 10                     FDA
# 10                     NPS
# 10                     TAM
# 10                      EV

# %%
def extract_momentum(momentum_dict, ticker):
    if ticker in momentum_dict:
        result = momentum_dict[ticker]
    else:
        result = 1
    return result

# %%
comment_ticker_split_df['momentum_factor'] = comment_ticker_split_df[['momentum_factor', 'symbol']].apply(lambda x: extract_momentum(x.momentum_factor, x.symbol), axis=1)
comment_ticker_split_df = comment_ticker_split_df.drop_duplicates()

# %%
comment_ticker_split_df.head(10)
# Out:
#    comment_id                                               text   timestamp  \
# 1     gpf8ky5  Honestly mods why didn't you make an actual GM...  1614698845
# 6     gpf8vly                           Let's just talk GME here  1614698980
# 8     gpf8w2i             Holding RKT and GME. Suck on that Mods  1614698986
# 9     gpf8wqh                            RKT TO THE MOON!!! 🚀🚀🌚🌚  1614698995
# 11    gpf8xou                                         I like GME  1614699007
# 14    gpf8yoh     This sub isn’t just a GME cesspool, jfc people  1614699021
# 15    gpf8z1l  So apparently GME thread gets deleted in SECON...  1614699025
# 19    gpf92y2  Very fishy...  no zjz posts no Unpopular pinnn...  1614699076
# 19    gpf92y2  Very fishy...  no zjz posts no Unpopular pinnn...  1614699076
# 22    gpf93e3  ![img](emote|wsb_emojis|bull) on CCIV / PLTR (...  1614699081
#
#    type  momentum_factor         symbol
# 1     C             10.0            GME
# 6     C             10.0            GME
# 8     C             10.0            GME
# 9     C             10.0           🚀🚀🌚🌚
# 11    C             10.0            GME
# 14    C             10.0            GME
# 15    C             10.0            GME
# 19    C             10.0      Unpopular
# 19    C              1.0            GME
# 22    C              1.0  CCIV / PLTR (

# %%
post_ticker_split_df['momentum_factor'] = post_ticker_split_df[['momentum_factor', 'symbol']].apply(lambda x: extract_momentum(x.momentum_factor, x.symbol), axis=1)
post_ticker_split_df = post_ticker_split_df.drop_duplicates()

# %%
post_ticker_split_df.head(10)
# Out:
#    post_id                                               text   timestamp  \
# 2   lw4i3o  Gentlemen,\n\nNow that the yield bubble is pop...  1614698764
# 3   lw4ihe  CVSI is on the move up! Buy low sell high! Hav...  1614698789
# 4   lw4ilh  There is probably some rule against this threa...  1614698796
# 8   lw4jqn  Mods surely know that no GME thread = spam in ...  1614698877
# 9   lw4juw   CBD Life Sciences Inc. is up today.  It's a C...  1614698887
# 9   lw4juw   CBD Life Sciences Inc. is up today.  It's a C...  1614698887
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
# 10  lw4k7e   \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913
#
#    type  momentum_factor                  symbol
# 2     P             10.0                    PLTR
# 3     P             10.0                    CVSI
# 4     P             10.0                     GME
# 8     P             10.0                     GME
# 9     P             10.0  CBD Life Sciences Inc.
# 9     P              1.0                  Amazon
# 10    P             10.0                     FDA
# 10    P              1.0                     NPS
# 10    P              1.0                     TAM
# 10    P              1.0                      EV

# %% [markdown]
# ### The symbol column can have both the company names and the ticker symbol, therefore we need to match both of them. The following queries are for this purpose

# %% [markdown]
# ### This query is used to match tickers from the symbol column of both the dataframes

# %%
ticker_match_query_string = f"""
 SELECT
 companyid, symbol
 FROM
  "equity-atlas_v3"."shareclassinfo"
 LIMIT 100000
""" 

df_ticker_match = pd.DataFrame(dnalab.query(ticker_match_query_string))

# %%
df_ticker_match.head(10)
# Out:
#     companyid  symbol
# 0  0C000036UT    NAFT
# 1  0C000009C8     8AK
# 2  0C0000AZ8H     PAL
# 3  0C00000I43     COG
# 4  0C000006WM  BHPG34
# 5  0C00006D96     CIX
# 6  0C000014PJ   ARGEF
# 7  0C00000NCL    DZV2
# 8  0C00000QI4    0NBX
# 9  0C00000XF9    GANT

# %% [markdown]
# ### This query is used to match actual company names from the symbol column of both the dataframes

# %%
company_match_query_string = f"""
 SELECT
 companyid, shortname AS symbol
 FROM
 "equity-atlas_v3"."companyinfo" 
 LIMIT 100000
"""

df_company_match = pd.DataFrame(dnalab.query(company_match_query_string))

# %%
df_company_match.head(10)
# Out:
#     companyid                  symbol
# 0  0C000006U4  Bank of Commerce Hldgs
# 1  0C000006V2             Baxter Intl
# 2  0C000006VC                     BCE
# 3  0C000006TA            Baker Hughes
# 4  0C000006T0                     AZZ
# 5  0C000006TJ      Ballistic Recovery
# 6  0C000006WE             Best Buy Co
# 7  0C00000726                   Bunge
# 8  0C0000BZIL               Luxbright
# 9  0C0000071J            Brown-Forman

# %%
comment_ticker_match_df = pd.merge(df_ticker_match, comment_ticker_split_df, on=['symbol'])
comment_company_match_df = pd.merge(df_company_match, comment_ticker_split_df, on=['symbol'])
final_comment_df = comment_ticker_match_df.append(comment_company_match_df)
final_comment_df.head(200)
# Out:
#       companyid    symbol comment_id  \
# 0    0C00000UKH       GME    gpf8ky5
# 1    0C00000UKH       GME    gpf8vly
# 2    0C00000UKH       GME    gpf8w2i
# 3    0C00000UKH       GME    gpf8xou
# 4    0C00000UKH       GME    gpf8yoh
# ..          ...       ...        ...
# 105  0C00000W3J       SLR    gpf9j57
# 106  0C00000IMZ       SLR    gpf9j57
# 107  0C000013S3      NAKD    gpf9iy5
# 0    0C000007ST  GameStop    gpf967y
# 1    0C000007ST  GameStop    gpf9b2i
#
#                                                   text   timestamp type  \
# 0    Honestly mods why didn't you make an actual GM...  1614698845    C
# 1                             Let's just talk GME here  1614698980    C
# 2               Holding RKT and GME. Suck on that Mods  1614698986    C
# 3                                           I like GME  1614699007    C
# 4       This sub isn’t just a GME cesspool, jfc people  1614699021    C
# ..                                                 ...         ...  ...
# 105  Bearish imo. If SLR is re-instated to pre 3/20...  1614699286    C
# 106  Bearish imo. If SLR is re-instated to pre 3/20...  1614699286    C
# 107  Bot.  Buying puts on NAKD.  Thanks.\n\nReally ...  1614699283    C
# 0    Sir, this is a GameStop dispensary.\n\n*I am a...  1614699117    C
# 1    Sir, this is a GameStop dispensary.\n\n*I am a...  1614699179    C
#
#      momentum_factor
# 0               10.0
# 1               10.0
# 2               10.0
# 3               10.0
# 4               10.0
# ..               ...
# 105             10.0
# 106             10.0
# 107             10.0
# 0               10.0
# 1               10.0
#
# [110 rows x 7 columns]

# %%
post_ticker_match_df = pd.merge(df_ticker_match, post_ticker_split_df, on=['symbol'])
post_company_match_df = pd.merge(df_company_match, post_ticker_split_df, on=['symbol'])
final_post_df = post_ticker_match_df.append(post_company_match_df)
final_post_df.head(200)
# Out:
#       companyid    symbol post_id  \
# 0    0C000009B9       FDA  lw4k7e
# 1    0C000009B9       FDA  lw4nrn
# 2    0C000009B9       FDA  lw4rj7
# 3    0C000009B9       FDA  lw4k7e
# 4    0C000009B9       FDA  lw4nrn
# ..          ...       ...     ...
# 153  0C00000SAL      KNOW  lw4rc5
# 154  0C00000BJN        IP  lw57p7
# 155  0C000014DD      SCAM  lw53jt
# 0    0C000008SF        RH  lw54kf
# 1    0C000007ST  GameStop  lw4ypy
#
#                                                   text   timestamp type  \
# 0     \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913    P
# 1     **POSITION 3000 SHARES AT $10.15**\n\nI’ve be...  1614699179    P
# 2     \n\n**POSITION 3000 SHARES AT $10.15**\n\nI’v...  1614699443    P
# 3     \n\n*Processing img qkp7svjbvmk61...*\n\n I’v...  1614698913    P
# 4     **POSITION 3000 SHARES AT $10.15**\n\nI’ve be...  1614699179    P
# ..                                                 ...         ...  ...
# 153  That hair, that smile, those glasses, that voi...  1614699428    P
# 154   \n\n**POSITION 3000 SHARES AT $10.15**\n\nI’v...  1614700562    P
# 155  I have forex courses of profitable traders for...  1614700295    P
# 0    I'm a bit scared that RH will fuck people on t...  1614700354    P
# 1    I COME TO EVERYONE HERE MY FELLOW PEOPLE.  We ...  1614699958    P
#
#      momentum_factor
# 0               10.0
# 1               10.0
# 2               10.0
# 3               10.0
# 4               10.0
# ..               ...
# 153             10.0
# 154             10.0
# 155             10.0
# 0               10.0
# 1               10.0
#
# [158 rows x 7 columns]

# %% [markdown]
# ### Save Extraction Files

# %%
final_comment_df.to_csv('extracted_comments.csv')
final_post_df.to_csv('extracted_posts.csv')

# %% [markdown]
# ### Zip CSV Files and Submit
