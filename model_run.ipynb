# %% [markdown]
# ### The `dnalab` Python package makes it easy to access data.

# %%
import dnalab

# %% [markdown]
# Here you can specify any file or folder your notebook might use based on this example.

# %%
# required_file = "file.csv"
# required_folder = "folder"
# required_code = "code.py"

# %% [markdown]
# From the Morningstar Extension on the left, try dragging into the notebook a table of data, Direct list, or Direct Search Criteria.

# %%
import spacy 
import pandas as pd
import os

# %%
PROJECT_PATH = os.getcwd()
POSTS_PATH = 'data/reddit_posts'
COMMENTS_PATH = 'data/reddit_comments'
POSTS_DATA_PATH = os.path.join(PROJECT_PATH, POSTS_PATH)
COMMENTS_DATA_PATH = os.path.join(PROJECT_PATH, COMMENTS_PATH)
print(POSTS_DATA_PATH, COMMENTS_DATA_PATH)
# Out:
# /home/rochak.chandra@morningstar.com/Rochak/wsb-hackathon/data/reddit_posts /home/rochak.chandra@morningstar.com/Rochak/wsb-hackathon/data/reddit_comments

# %% [markdown]
# ### Getting Dataframes

# %%
def get_df(input_path, output_path):
    pd.set_option('display.max_columns', None)
    all_files = glob.glob(input_path + "/*.csv")

    dfs = []

    for filename in all_files:
        df = pd.read_csv(filename, index_col=None)
        dfs.append(df)

    df = pd.concat(dfs, axis=0, ignore_index=True)
    non_nan_df = df[df['text'].notna()]
    filtered_df = non_nan_df[(non_nan_df['text'] != "[removed]") & (
        non_nan_df['text'] != '[deleted]')]
    filtered_df['date'] = filtered_df['timestamp'].apply(
        lambda x: datetime.fromtimestamp(x)).tolist()
    filtered_df.set_index('date', inplace=True)
    final_df = filtered_df.drop(filtered_df.columns[0], axis=1)
    final_df = final_df.sort_index()
    final_df = final_df[final_df.index.month == 3]
    final_df.to_csv(output_path)
    

    
def get_input(data_path, column):
    df = pd.read_csv(data_path, index_col='date', parse_dates=True)
    res = df[column].tolist()
    return res

# %%
BLACKLIST = ['bot', 'nyse']

# %% [markdown]
# ### Extract Symbols

# %%
def process(raw_comment, nlp):
    doc = nlp(raw_comment)
    res = []
    for ent in doc.ents:
        if ent.text.lower() not in BLACKLIST and ent.label_ == "ORG":
            res += ent
    return list(set(res))

# %%
posts_df = pd.read_csv(os.path.join(PROJECT_PATH, 'data/posts_df.csv'), parse_dates=True)

# %%
comments_df = pd.read_csv(os.path.join(PROJECT_PATH, 'data/comments_df.csv'), parse_dates=True)

# %%
posts_df.head(10)
# Out:
#                   date post_id  \
# 0  2021-03-02 09:25:06  lw4h9d
# 1  2021-03-02 09:25:57  lw4i0b
# 2  2021-03-02 09:26:04  lw4i3o
# 3  2021-03-02 09:26:29  lw4ihe
# 4  2021-03-02 09:26:36  lw4ilh
# 5  2021-03-02 09:26:47  lw4is2
# 6  2021-03-02 09:27:06  lw4j12
# 7  2021-03-02 09:27:42  lw4jj8
# 8  2021-03-02 09:27:57  lw4jqn
# 9  2021-03-02 09:28:07  lw4juw
#
#                                                 text  \
# 0  So loving this GME still going strong, that I ...
# 1  Is this being pushed here.  Been shareholder f...
# 2  Gentlemen,\n\nNow that the yield bubble is pop...
# 3  CVSI is on the move up! Buy low sell high! Hav...
# 4  There is probably some rule against this threa...
# 5                                      Fk these mods
# 6                              Because apparently so
# 7  🚀🚀🚀 BankOfSabadell  🚀🚀🚀🚀\n\n*Processing img 0b...
# 8  Mods surely know that no GME thread = spam in ...
# 9   CBD Life Sciences Inc. is up today.  It's a C...
#
#                                              title  upvote_ratio   timestamp  \
# 0                   GME and the righteous options?           1.0  1614698706
# 1                                 Rocket Companies           1.0  1614698757
# 2               Cathie Wood said PLTR is mandatory           1.0  1614698764
# 3                                             CVSI           1.0  1614698789
# 4  NOT the GME thread but share your thoughts here           1.0  1614698796
# 5                               Gee Emm Eey 3/2/21           1.0  1614698807
# 6                     RKT MEGATHREAD March 2, 2020           1.0  1614698826
# 7                          BankOfSanadell -- Spain           1.0  1614698862
# 8                     Something fishy is going on?           1.0  1614698877
# 9                                          CBDL Up           1.0  1614698887
#
#                author
# 0      Kick-Effective
# 1     Master-Unit6692
# 2  boomerbubblebuster
# 3           BigShr1mp
# 4   SwedishKillerChef
# 5        Mosaikmuster
# 6              iamzyb
# 7             NoFlySS
# 8     Crowbar_Freeman
# 9      ThisGuyAlright

# %%
comments_df.head(10)
# Out:
#                   date comment_id  \
# 0  2021-03-02 09:27:05    gpf8jcq
# 1  2021-03-02 09:27:25    gpf8ky5
# 2  2021-03-02 09:28:03    gpf8nvm
# 3  2021-03-02 09:28:07    gpf8o7q
# 4  2021-03-02 09:29:00    gpf8sfw
# 5  2021-03-02 09:29:38    gpf8vfy
# 6  2021-03-02 09:29:40    gpf8vly
# 7  2021-03-02 09:29:45    gpf8vyp
# 8  2021-03-02 09:29:46    gpf8w2i
# 9  2021-03-02 09:29:55    gpf8wqh
#
#                                                 text  score  awards  \
# 0  Heavy resistance at 124! Needs to move through...      1       0
# 1  Honestly mods why didn't you make an actual GM...      2       0
# 2                                            Squeeze      2       0
# 3                              And there she goes (:      2       0
# 4  Boom you see how quick she ran after blasting ...      1       0
# 5            No shit!\n\nhttps://fintel.io/ss/us/rkt      1       0
# 6                           Let's just talk GME here      3       0
# 7                                                 Fr      1       0
# 8             Holding RKT and GME. Suck on that Mods      1       0
# 9                            RKT TO THE MOON!!! 🚀🚀🌚🌚      1       0
#
#     timestamp               author  \t\t
# 0  1614698825              jsams14   NaN
# 1  1614698845    SwedishKillerChef   NaN
# 2  1614698883          elliskj1979   NaN
# 3  1614698887              SARMY1K   NaN
# 4  1614698940              jsams14   NaN
# 5  1614698978     robertleeblairjr   NaN
# 6  1614698980  HouseDowningVicodin   NaN
# 7  1614698985     420yolotrillswag   NaN
# 8  1614698986        gswblu3-1lead   NaN
# 9  1614698995            Young0Ice   NaN

# %%
comments_df_sample = comments_df.loc[1:10, ['comment_id', 'text', 'timestamp']]
posts_df_sample = posts_df.loc[1:10, ['post_id', 'text', 'timestamp']]

# %%
# !pip3 install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 14.8 MB/s eta 0:00:01
# Collecting pathy>=0.3.5
#   Downloading pathy-0.4.0-py3-none-any.whl (36 kB)
# Collecting thinc<8.1.0,>=8.0.2
#   Downloading thinc-8.0.2-cp38-cp38-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 108.3 MB/s eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.1
#   Downloading catalogue-2.0.1-py3-none-any.whl (9.6 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (4.54.1)
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.3-cp38-cp38-manylinux2014_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 85.7 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy) (49.6.0.post20210108)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.23.0)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 30.9 MB/s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 104.8 MB/s eta 0:00:01
# Collecting srsly<3.0.0,>=2.4.0
#   Downloading srsly-2.4.0-cp38-cp38-manylinux2014_x86_64.whl (458 kB)
#      |████████████████████████████████| 458 kB 72.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (1.19.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (20.8)
# Collecting spacy-legacy<3.1.0,>=3.0.0
#   Downloading spacy_legacy-3.0.2-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting smart-open<4.0.0,>=2.2.0
#   Downloading smart_open-3.0.0.tar.gz (113 kB)
#      |████████████████████████████████| 113 kB 100.8 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=9f42d2c6baa24fff497def2c759269c6f3dc41b4649b7879b7a2238453aef7da
#   Stored in directory: /home/jovyan/.cache/pip/wheels/11/73/9a/f91ac1f1816436b16423617c5be5db048697ff152a9c4346f2
# Successfully built smart-open
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, thinc, spacy-legacy, pathy, spacy
# Successfully installed blis-0.7.4 catalogue-2.0.1 cymem-2.0.5 murmurhash-1.0.5 pathy-0.4.0 preshed-3.0.5 pydantic-1.7.3 smart-open-3.0.0 spacy-3.0.5 spacy-legacy-3.0.2 srsly-2.4.0 thinc-8.0.2 typer-0.3.2 wasabi-0.8.2

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 18.1 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.23.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (49.6.0.post20210108)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.54.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.2)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /opt/conda/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !python3 -m spacy download en_core_web_trf

# %%
nlp = spacy.load("en_core_web_sm")

# %%
comments_df_sample['tokens'] = comments_df_sample['text'].apply(lambda x: process(x, nlp))

# %%
comments_df_sample.head(10)
